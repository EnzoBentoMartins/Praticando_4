# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['acertos_mat'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['acertos_por'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['acertos_geo'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['acertos_ing'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['acertos_his'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['acertos_fis'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['acertos_qui'])

df_concat = pd.concat([df_mat, df_por, df_geo, df_ing, df_his, df_fis, df_qui], axis=1)
df_concat
# Out:
#     acertos_mat  acertos_por  acertos_geo  acertos_ing  acertos_his  \
# 0             6            7            7            3            1
# 1            19           10            0            0            0
# 2            14           16            0            5            7
# 3            10            7            3            4            0
# 4             7            2            2            7            0
# ..          ...          ...          ...          ...          ...
# 95            6            4            7            1            4
# 96            8            1            4            6            1
# 97           23            5            0            2            4
# 98            0           10            3            1            5
# 99           11           15            0            1            6
#
#     acertos_fis  acertos_qui
# 0             8            3
# 1            11            8
# 2             4            4
# 3             0            8
# ...

# %%
# 1) Seu código aqui

df_percent = pd.DataFrame(columns=['percentual_mat'])
df_percent['percentual_mat'] = df_concat['acertos_mat'] / 24
df_percent['percentual_por'] = df_concat['acertos_por'] / 18
df_percent['percentual_geo'] = df_concat['acertos_geo'] / 8
df_percent['percentual_ing'] = df_concat['acertos_ing'] / 8
df_percent['percentual_his'] = df_concat['acertos_his'] / 8
df_percent['percentual_fis'] = df_concat['acertos_fis'] / 12
df_percent['percentual_qui'] = df_concat['acertos_qui'] / 12

df_percent
# Out:
#     percentual_mat  percentual_por  percentual_geo  percentual_ing  \
# 0         0.250000        0.388889           0.875           0.375
# 1         0.791667        0.555556           0.000           0.000
# 2         0.583333        0.888889           0.000           0.625
# 3         0.416667        0.388889           0.375           0.500
# 4         0.291667        0.111111           0.250           0.875
# ..             ...             ...             ...             ...
# 95        0.250000        0.222222           0.875           0.125
# 96        0.333333        0.055556           0.500           0.750
# 97        0.958333        0.277778           0.000           0.250
# 98        0.000000        0.555556           0.375           0.125
# 99        0.458333        0.833333           0.000           0.125
#
#     percentual_his  percentual_fis  percentual_qui
# 0            0.125        0.666667        0.250000
# 1            0.000        0.916667        0.666667
# ...

# %%
df_concat['soma_total'] = pd.DataFrame(np.sum(df_concat.T), columns=['total_acertos'])
df_concat['soma_total']
# Out:
# C:\Users\enzob\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# 0     36
# 1     49
# 2     51
# 3     33
# 4     31
#       ..
# 95    35
# 96    28
# 97    41
# 98    41
# 99    43
# Name: soma_total, Length: 100, dtype: int64

# %%
percent_geral = soma_tot / 90
percent_geral
# Out:
#     total_acertos
# 0        0.388889
# 1        0.533333
# 2        0.555556
# 3        0.355556
# 4        0.333333
# ..            ...
# 95       0.377778
# 96       0.300000
# 97       0.444444
# 98       0.444444
# 99       0.466667
#
# [100 rows x 1 columns]

# %%
soma_tot['aprovados'] = 0
soma_tot.loc[soma_tot['total_acertos'] > 45, 'aprovados'] = 1
alunos_aprovados = np.sum(soma_tot['aprovados'])
alunos_aprovados
# Out:
# 31

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
df_concat['reprovados'] = 0
df_concat.loc[df_concat['acertos_mat'] == 0, 'reprovados'] = 1
df_concat.loc[df_concat['acertos_fis'] == 0, 'reprovados'] = 1
df_concat.loc[df_concat['acertos_qui'] == 0, 'reprovados'] = 1

df_rep = pd.DataFrame(df_concat.loc[df_concat['reprovados'] == 1])
df_rep
# Out:
#     acertos_mat  acertos_por  acertos_geo  acertos_ing  acertos_his  \
# 3            10            7            3            4            0
# 6             6            0            7            7            5
# 10           10            8            3            2            1
# 12           20            8            3            7            1
# 14            7           11            1            7            1
# 20           23           11            6            5            6
# 25            0            4            7            4            0
# 26           11           14            6            2            7
# 27           21           13            1            5            7
# 33           14            8            0            5            6
# 35           11           14            6            3            3
# 49            8            1            1            0            1
# 56            7            6            7            5            6
# ...

# %%
alunos_rep = np.sum(df_rep['reprovados'])
alunos_rep
# Out:
# 23

# %%
media_geo = np.sum(df_rep['acertos_geo']) / len(df_rep)
media_his = np.sum(df_rep['acertos_his']) / len(df_rep)

media_his_geo = {'media_historia': media_his, 'media_geografia': media_geo}
media_his_geo
# Out:
# {'media_historia': 3.4347826086956523, 'media_geografia': 3.217391304347826}

# %%
df_concat['aprovados'] = 1
df_concat.loc[df_concat['acertos_mat'] == 0, 'aprovados'] = 0
df_concat.loc[df_concat['acertos_fis'] == 0, 'aprovados'] = 0
df_concat.loc[df_concat['acertos_qui'] == 0, 'aprovados'] = 0

df_rest = pd.DataFrame(df_concat.loc[df_concat['aprovados'] == 1])

df_aprov = pd.DataFrame(df_rest.loc[df_rest['soma_total'] > 45])
df_aprov
# Out:
#     acertos_mat  acertos_por  acertos_geo  acertos_ing  acertos_his  \
# 1            19           10            0            0            0
# 2            14           16            0            5            7
# 5            20            2            5            3            2
# 7            18            4            4            7            7
# 8            22            9            2            7            6
# 17           21           15            2            2            4
# 18           20            4            3            5            3
# 24           20            2            7            5            3
# 31           15           13            3            1            3
# 34           18           14            1            0            6
# 36           22            9            6            6            1
# 37           19           12            5            7            1
# 39            4           16            2            4            6
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-5ed92752-6121-474f-ab37-816918134afc.c000.csv'

# %%
pd.set_option('display.max_columns', None)
df.head(2)
# Out:
#                                  document_id  \
# 0  3bdb5e61-ee23-47b4-b36c-c22f3a5c7841-i0b0
# 1  ebca990f-65fd-43a1-9007-0eaf269b4cbb-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  e8f8f421b2c17ea52a1f066eafd3bf1b3fba0f10328137...              49
# 1  193100cf8bc5f851f1fba7f29ee0c76d2816fda686dae0...              31
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1971-03-15                          F                        5
# 1              1990-09-18                          F                       99
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0               INDIGENA                           120043.0
# 1         SEM INFORMACAO                           120032.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  \
# 0                      10.0           SANTA ROSA DO PURUS
# 1                      10.0                        JORDAO
#
# ...

# %%
df = pd.read_csv('part-00000-f720783d-f096-492e-a8d6-3c37db927048.c000.csv', sep=';')
df_vacinas = len(df['vacina_fabricante_nome'].unique())
df_vacinas
# Out:
# 13

# %%
df['paciente_id'].count()
# Out:
# 388589

# %%
# 3)
df_doses = df['vacina_descricao_dose'].unique()
df_doses
# Out:
# array(['1ª Dose', '2ª Dose', 'Reforço', '3ª Dose', 'Dose Adicional',
#        '2º Reforço', 'Única', 'Dose', '4ª Dose Revacinação',
#        '2ª Dose Revacinação', '1º Reforço', 'Revacinação',
#        '1ª Dose Revacinação', '3ª Dose Revacinação', '3º Reforço',
#        '5ª Dose Revacinação'], dtype=object)

# %%
# 3) solução alternativa
df_prim_dose = pd.DataFrame(df.loc[df['vacina_descricao_dose'] == '1ª Dose'])
df_prim_dose['vacina_descricao_dose'].count()
# Out:
# 143806

# %%
# 4)
df_men_idade = pd.DataFrame(df.loc[df['paciente_idade'] < 18])
df_men_idade['paciente_idade'].count()
# Out:
# 78120

# %%
# 5)
df_estab = len(df['estabelecimento_razaoSocial'].unique())
df_estab
# Out:
# 63

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_men_dezoito = df_men_idade.copy()
df_men_dezoito
# Out:
#                                       document_id  \
# 3       ec0e0b2b-62a2-44da-b86e-d703e9f89c19-i0b0
# 12      896a9776-01e5-4433-af85-241a2d130c81-i0b0
# 13      ec93ed9a-4454-4d18-9b4e-408d5559e0f9-i0b0
# 24      fec2df9f-4521-4628-afb8-b70781720974-i0b0
# 37      eee75786-c3dc-4859-8032-cb2cf63fb25c-i0b0
# ...                                           ...
# 388574  16edd785-5e58-4303-86e8-b38b67834611-i0b0
# 388580  182a4efe-9f85-483b-a461-50823782327f-i0b0
# 388583  187ca714-4122-45d8-b749-d1e33eb49da4-i0b0
# 388585  188db67e-851c-45e7-bd45-93ef3f71b81c-i0b0
# 388587  1953f621-764a-4a01-9840-ed9698db06fc-i0b0
#
#                                               paciente_id  paciente_idade  \
# 3       cf985fb380610c11fbe296d84429f2477ea94f2547c429...              13
# 12      03e0818e994282948754cef384c688b3ddaf80bb67662a...              14
# 13      ff72d9a9e9ee46fb23644ff04e7a5ecdbf84fcb7c0f552...              14
# ...

# %%
# 2)
list = []
list.append(df_men_dezoito.columns)
list
# Out:
# [Index(['document_id', 'paciente_id', 'paciente_idade',
#         'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#         'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#         'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#         'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#         'paciente_endereco_uf', 'paciente_endereco_cep',
#         'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#         'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#         'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#         'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#         'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#         'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#         'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#         'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#         'sistema_origem'],
# ...

# %%
# 3)
df_men_dezoito['vacina_categoria_nome'].count()
# Out:
# 57944

# %%
# 4)
list[0][14:20]
# Out:
# Index(['estabelecimento_valor', 'estabelecimento_razaoSocial',
#        'estalecimento_noFantasia', 'estabelecimento_municipio_codigo',
#        'estabelecimento_municipio_nome', 'estabelecimento_uf'],
#       dtype='object')

# %%
# 5)
select = df.loc[:, 'estabelecimento_valor': 'estabelecimento_uf']
select
# Out:
#         estabelecimento_valor  \
# 0                     6289312
# 1                     6430201
# 2                     2001314
# 3                     2001349
# 4                     6917291
# ...                       ...
# 388584                6917291
# 388585                6917291
# 388586                6992811
# 388587                6917291
# 388588                6917291
#
#                               estabelecimento_razaoSocial  \
# 0       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 1         DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 2                  PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 3                       PREFEITURA MUNICIPAL DE BRASILEIA
# 4                      PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                                                   ...
# 388584                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 388585                 PREFEITURA MUNICIPAL DE RIO BRANCO
# 388586             PREFEITURA MUNICIPAL DE SENA MADUREIRA
# ...

# %%
estab = pd.DataFrame(select['estabelecimento_razaoSocial'].drop_duplicates())
df_estab = select.iloc[estab.index]
df_estab
# Out:
#         estabelecimento_valor  \
# 0                     6289312
# 1                     6430201
# 2                     2001314
# 3                     2001349
# 4                     6917291
# ...                       ...
# 105433                9549838
# 134511                6801099
# 153302                2002116
# 169179                6076017
# 303702                3393984
#
#                               estabelecimento_razaoSocial  \
# 0       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 1         DISTRITO SANITARIO ESPECIAL INDIGENA ALTO JURUA
# 2                  PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 3                       PREFEITURA MUNICIPAL DE BRASILEIA
# 4                      PREFEITURA MUNICIPAL DE RIO BRANCO
# ...                                                   ...
# 105433                 A M COMERCIO E REPRESENTACOES LTDA
# 134511                CENTRO DE DIAGNOSTICOS CITOLAB LTDA
# 153302                            LUIZ AUGUSTO NO BATISTA
# ...
